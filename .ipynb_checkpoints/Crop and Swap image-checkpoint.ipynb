# %%
import cv2
import numpy as np
import matplotlib.pyplot as mpl

photo_1 = cv2.imread("photo-1.jpg")
photo_2 = cv2.imread("photo-2.jpg")


photo_1 = cv2.cvtColor(photo_1, cv2.COLOR_BGR2RGB)
photo_2 = cv2.cvtColor(photo_2, cv2.COLOR_BGR2RGB)

# %%
mpl.imshow(photo_1)

# %%
mpl.imshow(photo_2)

# %%
photo_cropped = photo_1[1020:1220, 580:800]

# %%
mpl.imshow(photo_cropped)

# %%
photo_cropped.shape
# Out:
# (200, 220, 3)

# %%
from PIL import Image
image = Image.open("photo-2.jpg")
photo_2 = image.resize((1500,1500))
photo_2.save("resize.jpg")
photo_new = cv2.imread("resize.jpg")

# %%
photo_new.shape
# Out:
# (1500, 1500, 3)

# %%
photo_new[10:210, 370:590 ] = photo_cropped

# %%
photo_new.shape
# Out:
# (1500, 1500, 3)

# %%
photo_new[10:210, 370:590 ] = photo_cropped

# %%
mpl.imshow(photo_new)
