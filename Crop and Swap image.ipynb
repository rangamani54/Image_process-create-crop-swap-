# %%
import cv2
import numpy as np
import matplotlib.pyplot as mpl

photo_1 = cv2.imread("photo-1.jpg")
photo_2 = cv2.imread("photo-2.jpg")   #CV by defualt gives the color in BGR but actual color is RGB


#photo_1 = cv2.cvtColor(photo_1, cv2.COLOR_BGR2RGB)
photo_2 = cv2.cvtColor(photo_2, cv2.COLOR_BGR2RGB)  #We have converted to RGB

# %%
mpl.imshow(photo_1)   #Showing the image with dimensions

# %%
mpl.imshow(photo_2)

# %%
photo_cropped = photo_1[1020:1220, 580:800]   #Cropped the sun part of the photo_1

# %%
mpl.imshow(photo_cropped)

# %%
photo_cropped.shape
# Out:
# (200, 220, 3)

# %%
#Chaging the shape or resizing the array or image (photo_2) into different dimensions as cropped part of photo-1 needs to be fit in the photo-2 

from PIL import Image
image = Image.open("photo-2.jpg")
photo_2 = image.resize((1500,1500))
photo_2.save("resize.jpg")
photo_new = cv2.imread("resize.jpg")

# %%
photo_new.shape
# Out:
# (1500, 1500, 3)

# %%
photo_new[480:680, 1150:1370 ] = photo_cropped    #Attaching the cropped part in photo-2 in specified dimensions and makes new image as photo_new

# %%
photo_new.shape
# Out:
# (1500, 1500, 3)

# %%
mpl.imshow(photo_new)    #New image after cropping

# %%
#2nd part Let's crop some part of photo_2 and attach it in photo_1
photo_cropped_2 = photo_new[810:1500, 0:1500]

# %%
photo_cropped_2.shape
# Out:
# (690, 1500, 3)

# %%
mpl.imshow(photo_cropped_2)

# %%
from PIL import Image                     #Resizing the photo_1 to fit the cropped part
image = Image.open("photo-1.jpg")
photo_1 = image.resize((2400,2000))
photo_1.save("resize2.jpg")
photo_new = cv2.imread("resize2.jpg")

# %%
photo_new.shape
# Out:
# (2000, 2400, 3)

# %%
mpl.imshow(photo_new)

# %%
photo_new[1310:2000, 0:1500 ] = photo_cropped_2    #Attaching cropped part pf photo_2 in resized new photo_new image of photo_1

# %%
mpl.imshow(photo_new)
